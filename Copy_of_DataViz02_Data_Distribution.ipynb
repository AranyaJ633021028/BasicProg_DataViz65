# %% [markdown]
# <a href="https://colab.research.google.com/github/AranyaJ633021028/BasicProg_DataViz65/blob/main/Copy_of_DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1]) #จุดแรกค่าในแกน x คือ 1 y คือ 2 #จุดสองค่าในแกน x คือ -1 y คือ -1

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name'])

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
df2.head()

# %% [markdown]
# สีแดง setosa
#
# เขียว versicolor
#
# น้ำเงิน virginica
#
# sepal กลีบเลี้ยง
# petal กลีบดอก

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %%
plt.scatter(df2['PetalLength'],df2['SepalWidth'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalWidth')

# %%
plt.scatter(df2['SepalLength'],df2['SepalWidth'],c=df2['Name'])
plt.xlabel('SepalLength')
plt.ylabel('SepalWidth')

# %% [markdown]
# กลีบดอกสั้น กลีบเลี้ยงกว้าง

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend() #กำหนดได้ว่าจะวางไว้ไหน ถ้าไม่กำหนดมันจะเลือกให้เองตรงที่ว่างที่ไม่ทับกราฟ
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('Comparing petal&sepal length of different iris flowers');

# %% [markdown]
# # New Section

# %% [markdown]
# ## ใช้ ขนาดของ marker ในการแสดงค่าใน column

# %%
#เอาความกว้างของกลีบดอกมาเป็นขนาดของวงกลม
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ขยายของขนาด marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## ปรับความโปรงใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers \n(sizes of the circle determine petal widths of the flowers)');

# %% [markdown]
# ## เปลี่ยน หน้าตาของ Marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$g$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth'])

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# #26/09/2022

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![1*2c21SkzJMf3frPXPAR_gZA-2.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength'])

# %%
plt.boxplot(df['SepalLength']) ; #ใส่ ; ให้ปิด output ที่ไม่เกี่ยวข้อง

# %%
plt.boxplot(df['SepalLength'],vert=False) #เป็นแนวนอน

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False) #เอาตัวแปรมารับ

# %% [markdown]
# median

# %%
ybp['medians'][0].get_ydata() #เอาค่าในแนวแกน y

# %%
ybp['medians'][0].get_xdata() #เอาค่าในแนวแกน x

# %%
ybp['medians'][0].get_xdata()[0]

# %% [markdown]
# whiskers

# %%
ybp['whiskers'] #มีสมาชิก 2 ตัว

# %%
ybp['whiskers'][0].get_xdata() #จุดที่ใกล้ที่สุด 1.5*IQR

# %% [markdown]
# min

# %%
min(ybp['whiskers'][0].get_xdata())

# %% [markdown]
# max

# %%
max(ybp['whiskers'][1].get_xdata())

# %% [markdown]
# caps

# %%
ybp['caps']

# %%
ybp['caps'][1].get_xdata()

# %% [markdown]
# q1

# %%
ybp['boxes'][0].get_xdata() #(5.1,5.1),(5.1,6.4),(6.4,6.4),(6.4,5.4)

# %%
ybp['boxes'][0].get_xdata()[0]

# %%
max(ybp['whiskers'][0].get_xdata())

# %% [markdown]
# Outlier

# %%
ybp['fliers']

# %%
ybp['fliers'][0].get_xdata() #ผลคือไม่มี outlier

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True) #ให้คำนวณ mean

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})

# %% [markdown]
# # Quiz กลุ่มfinal
#
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
bb = plt.boxplot(df['SepalLength'])

# %%
def detail_boxreturn(boxreturn):
    q1 = boxreturn['boxes'][0].get_ydata()[0]
    q2 = boxreturn['medians'][0].get_ydata()[0]
    q3 = boxreturn['boxes'][0].get_ydata()[2]
    minv = min(boxreturn['whiskers'][0].get_ydata())
    maxv = max(boxreturn['whiskers'][1].get_ydata())
    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn(bb)

# %%
bb2 = plt.boxplot(df['SepalLength'],vert=False)

# %%
detail_boxreturn(bb2)

# %%
def detail_boxreturn_v2(boxreturn, vert=True):
    if vert == True:
        q1 = boxreturn['boxes'][0].get_ydata()[0]
        q2 = boxreturn['medians'][0].get_ydata()[0]
        q3 = boxreturn['boxes'][0].get_ydata()[2]
        minv = min(boxreturn['whiskers'][0].get_ydata())
        maxv = max(boxreturn['whiskers'][1].get_ydata())     
    else: #vert == False
        q1 = boxreturn['boxes'][0].get_xdata()[0]
        q2 = boxreturn['medians'][0].get_xdata()[0]
        q3 = boxreturn['boxes'][0].get_xdata()[2]
        minv = min(boxreturn['whiskers'][0].get_xdata())
        maxv = max(boxreturn['whiskers'][1].get_xdata())   

    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn_v2(bb)

# %%
detail_boxreturn_v2(bb2,vert=False)

# %%
plt.boxplot(df['PetalLength'][:50],positions = [1] )
plt.boxplot(df['PetalLength'][50:100],positions = [2] )
plt.boxplot(df['PetalLength'][100:150],positions = [3] );

# %% [markdown]
# # Violin plot

# %%
bb = plt.boxplot(df['PetalLength'][:50])

# %%
plt.violinplot(df['PetalLength'][:50])

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True)

# %% [markdown]
# # Quiz 6 ให้เปรียบเทียบการกระจายตัวของราคาบ้านเดี่ยวและคอนโด ระหว่างจังหวัดกทม ขอนแก่น และเชียงใหม่ (ด้วย boxplot)

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
unit = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')
unit.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN             37.3  2500000.0  ...               1.0
# 1               40.0            150.0  2390000.0  ...               NaN
# 2                NaN             28.0        NaN  ...               NaN
# 3                NaN             27.0   170000.0  ...               NaN
# 4                NaN            182.0  2390000.0  ...               1.0
#
#    count_room_kitchen  count_room_living  count_room_maid  count_room_storage  \
# 0                 1.0                NaN              NaN                 NaN
# 1                 NaN                NaN              NaN                 NaN
# 2                 NaN                NaN              NaN                 NaN
# 3                 NaN                NaN              NaN                 NaN
# 4                 1.0                NaN              NaN                 2.0
#
#    count_room_utility         date_created         date_updated  source  \
# 0                 NaN  2021-11-19 18:00:09  2021-11-19 17:44:45  baania
# 1                 NaN  2022-01-27 14:30:04  2022-01-27 14:22:55  baania
# 2                 NaN  2022-01-14 15:00:10  2022-01-14 14:40:04  baania
# 3                 NaN  2020-12-04 10:40:59  2020-10-14 01:06:48  baania
# 4                 NaN  2021-11-12 13:30:08  2021-02-03 12:12:54  baania
#
#                                         url_unittype
# 0  https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 1  https://baania.com/th/project/เซน-บาย-ศิวาลัย-...
# 2  https://baania.com/th/project/วันพลัส-นายน์ทีน...
# 3  https://baania.com/th/project/บ้านสวนชมน้ำ-776...
# 4  https://baania.com/th/project/เบล็สทาวน์-ศรีนค...
#
# [5 rows x 27 columns]

# %%
project = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_project.csv')
project.head()
# Out:
#    row_number                project_id                             name_en  \
# 0      7880.0  5ee08d64dda791001299b2a6  Winning Residence Sukhumvit Praksa
# 1     16689.0             project_11326                    Gift Condominium
# 2       290.0  62739c4089233e001362b001    Sanrak 9 Sukprayoon Nong Krathum
# 3     20719.0              project_2010                     Baan Sansabai 1
# 4       199.0             project_16838          Baanpruksa Ratchapruek-345
#
#                               name_th propertytype_id propertytype_name_en  \
# 0  วินนิ่ง เรสซิเดนท์ สุขุมวิท แพรกษา               1       Detached House
# 1                 กิ๊ฟท์ คอนโดมิเนียม               2                Condo
# 2      แสนรัก 9 ศุขประยูร หนองกระทุ่ม               3             Townhome
# 3                       บ้านแสนสบาย 1               1       Detached House
# 4              บ้านพฤกษา ราชพฤกษ์-345               3             Townhome
#
#   propertytype_name_th  price_min     developer_id  \
# 0                 บ้าน  3790000.0  developer_10678
# 1                คอนโด  1100000.0   developer_7319
# 2             ทาวน์โฮม        0.0  developer_10510
# 3                 บ้าน        0.0  developer_10510
# 4             ทาวน์โฮม  1930000.0   developer_1026
#
#               developer_name_en  ... facility_meeting  facility_park  \
# 0  Winning Asset Plus Co., Ltd.  ...              NaN            NaN
# 1      Gift Asset Land Co.,Ltd.  ...              NaN            1.0
# 2                           NaN  ...              NaN            NaN
# 3                           NaN  ...              NaN            NaN
# 4  Preuksa Real Estate Co.,Ltd.  ...              NaN            1.0
#
#    facility_playground facility_pool facility_security         date_created  \
# 0                  NaN           1.0               1.0  2020-06-10 14:36:04
# 1                  NaN           1.0               1.0  2017-10-30 15:38:48
# 2                  NaN           NaN               NaN  2022-05-05 16:43:28
# 3                  NaN           NaN               NaN  2016-09-05 15:32:15
# 4                  NaN           1.0               1.0  2019-09-05 11:49:37
#
#            date_finish         date_updated  source  \
# 0                  NaN  2020-12-04 10:32:58  baania
# 1  2013-01-01 07:00:00  2020-12-04 10:49:00  baania
# 2                  NaN  2022-05-05 17:30:03  baania
# 3  1970-01-02 07:00:00  2020-12-04 10:45:31  baania
# 4  1970-01-02 07:00:00  2021-03-17 12:00:04  baania
#
#                                          url_project
# 0  https://baania.com/th/project/วินนิ่ง-เรสซิเดน...
# 1  https://baania.com/th/project/กิ๊ฟท์-คอนโดมิเน...
# 2  https://baania.com/th/project/แสนรัก-9-ศุขประย...
# 3  https://baania.com/th/project/บ้านแสนสบาย-1-pr...
# 4  https://baania.com/th/project/บ้านพฤกษา-ราชพฤก...
#
# [5 rows x 45 columns]

# %%
project_nodup = project.drop_duplicates(subset=['project_id'])

# %%
unit['province'] = unit['project_id'].map(project_nodup.set_index('project_id')['province_name_th'])
unit.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_kitchen  \
# 0                NaN             37.3  2500000.0  ...                 1.0
# 1               40.0            150.0  2390000.0  ...                 NaN
# 2                NaN             28.0        NaN  ...                 NaN
# 3                NaN             27.0   170000.0  ...                 NaN
# 4                NaN            182.0  2390000.0  ...                 1.0
#
#    count_room_living  count_room_maid  count_room_storage  count_room_utility  \
# 0                NaN              NaN                 NaN                 NaN
# 1                NaN              NaN                 NaN                 NaN
# 2                NaN              NaN                 NaN                 NaN
# 3                NaN              NaN                 NaN                 NaN
# 4                NaN              NaN                 2.0                 NaN
#
#           date_created         date_updated  source  \
# 0  2021-11-19 18:00:09  2021-11-19 17:44:45  baania
# 1  2022-01-27 14:30:04  2022-01-27 14:22:55  baania
# 2  2022-01-14 15:00:10  2022-01-14 14:40:04  baania
# 3  2020-12-04 10:40:59  2020-10-14 01:06:48  baania
# 4  2021-11-12 13:30:08  2021-02-03 12:12:54  baania
#
#                                         url_unittype       province
# 0  https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...  กรุงเทพมหานคร
# 1  https://baania.com/th/project/เซน-บาย-ศิวาลัย-...      เชียงใหม่
# 2  https://baania.com/th/project/วันพลัส-นายน์ทีน...      เชียงใหม่
# 3  https://baania.com/th/project/บ้านสวนชมน้ำ-776...        นนทบุรี
# 4  https://baania.com/th/project/เบล็สทาวน์-ศรีนค...    สมุทรปราการ
#
# [5 rows x 28 columns]

# %%
unit.dropna(subset=['propertytype_name_en','price_min','area_usable_min'],inplace=True)

# %% [markdown]
# ### cm

# %%
cm = unit[unit['province']=='เชียงใหม่']
cm
# Out:
#        row_number               unittype_id                project_id  \
# 1           28777            unittype_10267              project_3543
# 21          10064             unittype_1888                project_36
# 25          17337  5f2d048d306e7e0019068fad  5f2cdf27306e7e0019068f25
# 35           6309             unittype_3461               project_754
# 48          31164              unittype_267                project_84
# ...           ...                       ...                       ...
# 42501        8297              unittype_132                project_54
# 42516       18541  5fb3a735ee0d7f0012409fb0  5fb3a4032aaf680012207eae
# 42526        3221              unittype_105                project_48
# 42568       36846            unittype_37618             project_16502
# 42602       39384             unittype_3476               project_812
#
#                    name_th  propertytype_id propertytype_name_en  \
# 1       บ้านแฝดสองชั้น Z-2            20000           Twin house
# 21     House Type & Plan 1                1       Detached House
# 25        โฮมออฟฟิศสามชั้น                6          Home office
# 35                  Type C                1       Detached House
# 48     Office Villa Type A                4           Commercial
# ...                    ...              ...                  ...
# 42501          ศิวรินทร์ A                1       Detached House
# 42516  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 42526                LLT50                1       Detached House
# 42568            1 Bedroom                2                Condo
# 42602     2 Bedroom Type A                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 1                  บ้านแฝด               40.0            150.0   2390000.0
# 21                    บ้าน                NaN            300.0   7500000.0
# 25               โฮมออฟฟิศ                NaN            210.0   6300000.0
# 35                    บ้าน                NaN            390.0  11000000.0
# 48            อาคารพาณิชย์               25.0            205.0   5250000.0
# ...                    ...                ...              ...         ...
# 42501                 บ้าน               57.0            176.0   3590000.0
# 42516                 บ้าน                NaN             82.0   1590000.0
# 42526                 บ้าน                NaN             50.0    650000.0
# 42568                คอนโด                NaN             74.0   5500000.0
# 42602                คอนโด                NaN             94.0   6345000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 1      ...                 NaN                NaN              NaN
# 21     ...                 NaN                NaN              NaN
# 25     ...                 NaN                1.0              NaN
# 35     ...                 1.0                1.0              NaN
# 48     ...                 NaN                NaN              NaN
# ...    ...                 ...                ...              ...
# 42501  ...                 1.0                NaN              NaN
# 42516  ...                 NaN                NaN              NaN
# 42526  ...                 1.0                NaN              NaN
# 42568  ...                 NaN                NaN              NaN
# 42602  ...                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 1                     NaN                 NaN  2022-01-27 14:30:04
# 21                    NaN                 NaN  2021-11-12 13:25:19
# 25                    NaN                 NaN  2021-11-12 13:18:59
# 35                    NaN                 NaN  2020-12-04 10:44:19
# 48                    NaN                 NaN  2021-11-12 13:25:43
# ...                   ...                 ...                  ...
# 42501                 NaN                 NaN  2021-11-12 13:17:23
# 42516                 NaN                 NaN  2021-11-12 13:25:45
# 42526                 NaN                 NaN  2022-01-25 15:00:12
# 42568                 NaN                 NaN  2021-11-12 13:23:00
# 42602                 NaN                 NaN  2022-01-14 11:00:11
#
#               date_updated  source  \
# 1      2022-01-27 14:22:55  baania
# 21     2020-11-02 16:46:41  baania
# 25     2020-08-07 14:38:19  baania
# 35     2020-10-14 21:21:23  baania
# 48     2020-11-17 15:06:51  baania
# ...                    ...     ...
# 42501  2019-07-25 15:32:13  baania
# 42516  2020-11-17 17:34:51  baania
# 42526  2022-01-25 14:40:03  baania
# 42568  2020-10-14 20:28:49  baania
# 42602  2022-01-14 10:32:44  baania
#
#                                             url_unittype   province
# 1      https://baania.com/th/project/เซน-บาย-ศิวาลัย-...  เชียงใหม่
# 21     https://baania.com/th/project/ลานนาซิตี้ปาร์ค-...  เชียงใหม่
# 25     https://baania.com/th/project/นิวเอจ-สตูดิโอเฮ...  เชียงใหม่
# 35     https://baania.com/th/project/บ้านล้านนาธารา-เ...  เชียงใหม่
# 48     https://baania.com/th/project/มาลาดา-โฮม-แอนด์...  เชียงใหม่
# ...                                                  ...        ...
# 42501  https://baania.com/th/project/ศิวาลัย-วิลเลจ-4...  เชียงใหม่
# 42516  https://baania.com/th/project/กานต์รวี-2-5fb3a...  เชียงใหม่
# 42526  https://baania.com/th/project/ล้านนาเลควิว-เชี...  เชียงใหม่
# 42568  https://baania.com/th/project/ปันนา-เรสซิเดนซ์...  เชียงใหม่
# 42602  https://baania.com/th/project/เดอะ-ยูนีค-คอนโด...  เชียงใหม่
#
# [2438 rows x 28 columns]

# %%
unit_cm_condo = cm[(cm['propertytype_name_en']=='Condo')]
unit_cm_condo
# Out:
#        row_number               unittype_id                project_id  \
# 326         34034              unittype_743               project_236
# 329         40022  60669943ca1e9b0013db1ac7  606698d3f6029500156e608d
# 340          8942            unittype_37616             project_16124
# 370         41479  61e0009f25ee250014de3489  61dffc0e25ee250014de3481
# 372         41536  61e7b9bb48e11a00140bc1ba  61e7b8a525ee250014de35cc
# ...           ...                       ...                       ...
# 42307       34171             unittype_1847               project_962
# 42446       38010            unittype_38908             project_17016
# 42463       33940              unittype_179                project_62
# 42568       36846            unittype_37618             project_16502
# 42602       39384             unittype_3476               project_812
#
#                 name_th  propertytype_id propertytype_name_en  \
# 326           1 Bedroom                2                Condo
# 329          Single Bed                2                Condo
# 340           1 Bedroom                2                Condo
# 370              Studio                2                Condo
# 372           1 Bedroom                2                Condo
# ...                 ...              ...                  ...
# 42307         1 Bedroom                2                Condo
# 42446            Studio                2                Condo
# 42463      Duplex Room                 2                Condo
# 42568         1 Bedroom                2                Condo
# 42602  2 Bedroom Type A                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 326                  คอนโด                NaN             29.0  1590000.0
# 329                  คอนโด                NaN             23.0  1530000.0
# 340                  คอนโด                NaN             53.0  2700000.0
# 370                  คอนโด                NaN             22.0  1570000.0
# 372                  คอนโด                NaN             30.0  2190000.0
# ...                    ...                ...              ...        ...
# 42307                คอนโด                NaN             38.0   700000.0
# 42446                คอนโด                NaN             26.0   979000.0
# 42463                คอนโด                NaN             48.0  3235000.0
# 42568                คอนโด                NaN             74.0  5500000.0
# 42602                คอนโด                NaN             94.0  6345000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 326    ...                 NaN                NaN              NaN
# 329    ...                 NaN                NaN              NaN
# 340    ...                 NaN                NaN              NaN
# 370    ...                 NaN                NaN              NaN
# 372    ...                 NaN                NaN              NaN
# ...    ...                 ...                ...              ...
# 42307  ...                 NaN                NaN              NaN
# 42446  ...                 NaN                NaN              NaN
# 42463  ...                 NaN                NaN              NaN
# 42568  ...                 NaN                NaN              NaN
# 42602  ...                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 326                   NaN                 NaN  2021-11-12 13:20:42
# 329                   NaN                 NaN  2022-01-26 15:00:11
# 340                   NaN                 NaN  2021-11-12 13:22:59
# 370                   NaN                 NaN  2022-01-13 18:00:07
# 372                   NaN                 NaN  2022-01-19 15:30:06
# ...                   ...                 ...                  ...
# 42307                 NaN                 NaN  2020-12-04 10:43:35
# 42446                 NaN                 NaN  2022-01-17 14:00:13
# 42463                 NaN                 NaN  2021-11-12 13:25:14
# 42568                 NaN                 NaN  2021-11-12 13:23:00
# 42602                 NaN                 NaN  2022-01-14 11:00:11
#
#               date_updated  source  \
# 326    2020-10-14 00:56:21  baania
# 329    2022-01-26 14:43:32  baania
# 340    2020-10-14 20:26:08  baania
# 370    2022-01-13 17:38:48  baania
# 372    2022-01-19 14:12:34  baania
# ...                    ...     ...
# 42307  2020-10-14 20:43:09  baania
# 42446  2022-01-17 13:44:39  baania
# 42463  2020-10-27 14:41:06  baania
# 42568  2020-10-14 20:28:49  baania
# 42602  2022-01-14 10:32:44  baania
#
#                                             url_unittype   province
# 326    https://baania.com/th/project/พรอมท์คอนโด-236/...  เชียงใหม่
# 329    https://baania.com/th/project/ฟินน์-คอนโด-2-สว...  เชียงใหม่
# 340    https://baania.com/th/project/ปันนา-เรสซิเดนซ์...  เชียงใหม่
# 370    https://baania.com/th/project/มหิดล-คอนโด-61df...  เชียงใหม่
# 372    https://baania.com/th/project/วันพลัส-สวนดอก-1...  เชียงใหม่
# ...                                                  ...        ...
# 42307  https://baania.com/th/project/คอนโดมิเนียม-นคร...  เชียงใหม่
# 42446  https://baania.com/th/project/ซินเนีย-คอนโด-17...  เชียงใหม่
# 42463  https://baania.com/th/project/วี-เรสซิเดนท์-62...  เชียงใหม่
# 42568  https://baania.com/th/project/ปันนา-เรสซิเดนซ์...  เชียงใหม่
# 42602  https://baania.com/th/project/เดอะ-ยูนีค-คอนโด...  เชียงใหม่
#
# [601 rows x 28 columns]

# %%
unit_cm_dth = cm[(cm['propertytype_name_en']=='Detached House')]
unit_cm_dth
# Out:
#        row_number               unittype_id                project_id  \
# 21          10064             unittype_1888                project_36
# 35           6309             unittype_3461               project_754
# 51          14631  5e85b674e146a400123ef326  5e85b506e146a400123ef324
# 52          20751             unittype_3543              project_1048
# 87           4964                unittype_9                project_20
# ...           ...                       ...                       ...
# 42434       10094              unittype_207                project_70
# 42470       20895              unittype_336               project_100
# 42501        8297              unittype_132                project_54
# 42516       18541  5fb3a735ee0d7f0012409fb0  5fb3a4032aaf680012207eae
# 42526        3221              unittype_105                project_48
#
#                    name_th  propertytype_id propertytype_name_en  \
# 21     House Type & Plan 1                1       Detached House
# 35                  Type C                1       Detached House
# 51     บ้านเดี่ยวชั้นเดียว                1       Detached House
# 52                พรทิวา 2                1       Detached House
# 87                   Daisy                1       Detached House
# ...                    ...              ...                  ...
# 42434                Cuore                1       Detached House
# 42470             บ้านภูคำ                1       Detached House
# 42501          ศิวรินทร์ A                1       Detached House
# 42516  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 42526                LLT50                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 21                    บ้าน                NaN            300.0   7500000.0
# 35                    บ้าน                NaN            390.0  11000000.0
# 51                    บ้าน                NaN            137.0   2590000.0
# 52                    บ้าน                NaN             88.0   1645625.0
# 87                    บ้าน                NaN            120.0   3280000.0
# ...                    ...                ...              ...         ...
# 42434                 บ้าน                NaN            185.0   3830000.0
# 42470                 บ้าน                NaN            145.0   3390000.0
# 42501                 บ้าน               57.0            176.0   3590000.0
# 42516                 บ้าน                NaN             82.0   1590000.0
# 42526                 บ้าน                NaN             50.0    650000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 21     ...                 NaN                NaN              NaN
# 35     ...                 1.0                1.0              NaN
# 51     ...                 1.0                NaN              NaN
# 52     ...                 NaN                NaN              NaN
# 87     ...                 NaN                NaN              NaN
# ...    ...                 ...                ...              ...
# 42434  ...                 1.0                NaN              NaN
# 42470  ...                 NaN                NaN              NaN
# 42501  ...                 1.0                NaN              NaN
# 42516  ...                 NaN                NaN              NaN
# 42526  ...                 1.0                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 21                    NaN                 NaN  2021-11-12 13:25:19
# 35                    NaN                 NaN  2020-12-04 10:44:19
# 51                    NaN                 NaN  2021-11-12 13:25:47
# 52                    NaN                 NaN  2020-12-04 10:44:04
# 87                    NaN                 NaN  2022-01-11 17:00:08
# ...                   ...                 ...                  ...
# 42434                 1.0                 NaN  2022-02-04 17:00:10
# 42470                 NaN                 NaN  2022-01-26 17:30:03
# 42501                 NaN                 NaN  2021-11-12 13:17:23
# 42516                 NaN                 NaN  2021-11-12 13:25:45
# 42526                 NaN                 NaN  2022-01-25 15:00:12
#
#               date_updated  source  \
# 21     2020-11-02 16:46:41  baania
# 35     2020-10-14 21:21:23  baania
# 51     2020-11-18 14:09:03  baania
# 52     2020-10-14 21:09:01  baania
# 87     2022-01-11 16:44:20  baania
# ...                    ...     ...
# 42434  2022-02-04 16:35:35  baania
# 42470  2022-01-26 17:02:47  baania
# 42501  2019-07-25 15:32:13  baania
# 42516  2020-11-17 17:34:51  baania
# 42526  2022-01-25 14:40:03  baania
#
#                                             url_unittype   province
# 21     https://baania.com/th/project/ลานนาซิตี้ปาร์ค-...  เชียงใหม่
# 35     https://baania.com/th/project/บ้านล้านนาธารา-เ...  เชียงใหม่
# 51     https://baania.com/th/project/บ้านถุงทอง-แอท-บ...  เชียงใหม่
# 52     https://baania.com/th/project/บ้านสมหวังคันทรี...  เชียงใหม่
# 87     https://baania.com/th/project/บ้านนนนิภา-แม่โจ...  เชียงใหม่
# ...                                                  ...        ...
# 42434  https://baania.com/th/project/พิลโล่-36-70/cuo...  เชียงใหม่
# 42470  https://baania.com/th/project/ภูฟ้าการ์เด้นท์โ...  เชียงใหม่
# 42501  https://baania.com/th/project/ศิวาลัย-วิลเลจ-4...  เชียงใหม่
# 42516  https://baania.com/th/project/กานต์รวี-2-5fb3a...  เชียงใหม่
# 42526  https://baania.com/th/project/ล้านนาเลควิว-เชี...  เชียงใหม่
#
# [1540 rows x 28 columns]

# %% [markdown]
# ### bkk

# %%
bkk = unit[unit['province']=='กรุงเทพมหานคร']
bkk
# Out:
#        row_number               unittype_id                project_id  \
# 0           27501             unittype_9565              project_2446
# 5           30766             unittype_8026              project_2694
# 11           2452             unittype_8521              project_2906
# 17           6700            unittype_20615              project_8068
# 22           8227            unittype_36858             project_15801
# ...           ...                       ...                       ...
# 42606       24384            unittype_14126              project_5602
# 42607       13546            unittype_40152             project_17505
# 42610       33124            unittype_21700              project_8631
# 42614       41022  617fc61e551dd10015a6933e  617fc4d3f62011001350de55
# 42623        9333            unittype_37375             project_16389
#
#                    name_th  propertytype_id propertytype_name_en  \
# 0                2 Bedroom                2                Condo
# 5            Luciano Grand                1       Detached House
# 11      New Villa Valdivia                1       Detached House
# 17     2 Bedroom (ขายแล้ว)                2                Condo
# 22               2 Bedroom                2                Condo
# ...                    ...              ...                  ...
# 42606      ทาวน์โฮมสามชั้น                3             Townhome
# 42607            2 Bedroom                2                Condo
# 42610  อาคารพาณิชย์สามชั้น                4           Commercial
# 42614      ทาวน์โฮมสามชั้น                3             Townhome
# 42623  บ้านเดี่ยวชั้นเดียว                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 0                    คอนโด                NaN             37.3   2500000.0
# 5                     บ้าน               70.5            198.0  11700000.0
# 11                    บ้าน                NaN            441.0  36900000.0
# 17                   คอนโด                NaN             57.0   4008000.0
# 22                   คอนโด                NaN             80.0   2500000.0
# ...                    ...                ...              ...         ...
# 42606             ทาวน์โฮม                NaN            349.0  18000000.0
# 42607                คอนโด                NaN             71.0  17000000.0
# 42610         อาคารพาณิชย์                NaN            250.0   5990000.0
# 42614             ทาวน์โฮม                NaN            142.1   4880000.0
# 42623                 บ้าน                NaN            180.0   3200000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 0      ...                 1.0                NaN              NaN
# 5      ...                 NaN                NaN              NaN
# 11     ...                 1.0                1.0              1.0
# 17     ...                 NaN                NaN              NaN
# 22     ...                 NaN                NaN              NaN
# ...    ...                 ...                ...              ...
# 42606  ...                 2.0                NaN              NaN
# 42607  ...                 1.0                1.0              NaN
# 42610  ...                 NaN                NaN              NaN
# 42614  ...                 NaN                NaN              NaN
# 42623  ...                 1.0                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 0                     NaN                 NaN  2021-11-19 18:00:09
# 5                     NaN                 NaN  2021-11-12 13:22:43
# 11                    NaN                 NaN  2021-11-12 13:22:43
# 17                    NaN                 NaN  2021-11-12 13:31:06
# 22                    NaN                 NaN  2021-11-12 13:20:31
# ...                   ...                 ...                  ...
# 42606                 NaN                 NaN  2020-12-04 10:45:58
# 42607                 NaN                 NaN  2021-11-12 13:23:03
# 42610                 NaN                 NaN  2020-12-04 10:46:14
# 42614                 NaN                 NaN  2021-11-12 13:34:18
# 42623                 NaN                 NaN  2020-12-04 10:42:26
#
#               date_updated  source  \
# 0      2021-11-19 17:44:45  baania
# 5      2020-10-14 19:35:20  baania
# 11     2020-10-14 19:35:47  baania
# 17     2021-03-18 16:04:05  baania
# 22     2020-10-14 00:55:39  baania
# ...                    ...     ...
# 42606  2020-10-14 22:59:34  baania
# 42607  2020-10-14 20:30:43  baania
# 42610  2020-10-14 23:19:16  baania
# 42614  2021-11-02 09:42:40  baania
# 42623  2020-10-14 19:30:46  baania
#
#                                             url_unittype       province
# 0      https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...  กรุงเทพมหานคร
# 5      https://baania.com/th/project/คาซ่า-แกรนด์-ตาก...  กรุงเทพมหานคร
# 11     https://baania.com/th/project/แกรนด์-บางกอก-บู...  กรุงเทพมหานคร
# 17     https://baania.com/th/project/ศุภาลัย-ซิตี้-รี...  กรุงเทพมหานคร
# 22     https://baania.com/th/project/เดอะ-ทรีโอ-การ์เ...  กรุงเทพมหานคร
# ...                                                  ...            ...
# 42606  https://baania.com/th/project/เดอะ-ซีนีธ-5602/...  กรุงเทพมหานคร
# 42607  https://baania.com/th/project/เดอะ-ไลน์-สาทร-1...  กรุงเทพมหานคร
# 42610  https://baania.com/th/project/พลอยไพลิน-เพลส-8...  กรุงเทพมหานคร
# 42614  https://baania.com/th/project/บ้านกลางเมือง-สุ...  กรุงเทพมหานคร
# 42623  https://baania.com/th/project/ณรงค์กิจ-รามอินท...  กรุงเทพมหานคร
#
# [10583 rows x 28 columns]

# %%
unit_bkk_condo = bkk[(bkk['propertytype_name_en']=='Condo')]
unit_bkk_condo
# Out:
#        row_number     unittype_id     project_id              name_th  \
# 0           27501   unittype_9565   project_2446            2 Bedroom
# 17           6700  unittype_20615   project_8068  2 Bedroom (ขายแล้ว)
# 22           8227  unittype_36858  project_15801            2 Bedroom
# 26          26382   unittype_9188   project_3143            2 Bedroom
# 27          27690  unittype_18893   project_5809            1 Bedroom
# ...           ...             ...            ...                  ...
# 42564        8226  unittype_36857  project_15801            1 Bedroom
# 42570       28191  unittype_19590   project_4668            2 Bedroom
# 42585       21493   unittype_7895   project_2625            1 Bedroom
# 42604        1058   unittype_7949   project_2641    Typical 1 Bedroom
# 42607       13546  unittype_40152  project_17505            2 Bedroom
#
#        propertytype_id propertytype_name_en propertytype_name_th  \
# 0                    2                Condo                คอนโด
# 17                   2                Condo                คอนโด
# 22                   2                Condo                คอนโด
# 26                   2                Condo                คอนโด
# 27                   2                Condo                คอนโด
# ...                ...                  ...                  ...
# 42564                2                Condo                คอนโด
# 42570                2                Condo                คอนโด
# 42585                2                Condo                คอนโด
# 42604                2                Condo                คอนโด
# 42607                2                Condo                คอนโด
#
#        area_total_min_wa  area_usable_min   price_min  ...  \
# 0                    NaN             37.3   2500000.0  ...
# 17                   NaN             57.0   4008000.0  ...
# 22                   NaN             80.0   2500000.0  ...
# 26                   NaN             51.0   3500000.0  ...
# 27                   NaN             28.0   1750000.0  ...
# ...                  ...              ...         ...  ...
# 42564                NaN             64.0   2000000.0  ...
# 42570                NaN             87.0   7350000.0  ...
# 42585                NaN             26.0   3750000.0  ...
# 42604                NaN             34.0   3120000.0  ...
# 42607                NaN             71.0  17000000.0  ...
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 0                     1.0                NaN              NaN
# 17                    NaN                NaN              NaN
# 22                    NaN                NaN              NaN
# 26                    1.0                1.0              NaN
# 27                    1.0                1.0              NaN
# ...                   ...                ...              ...
# 42564                 NaN                NaN              NaN
# 42570                 NaN                NaN              NaN
# 42585                 1.0                NaN              NaN
# 42604                 1.0                1.0              NaN
# 42607                 1.0                1.0              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 0                     NaN                 NaN  2021-11-19 18:00:09
# 17                    NaN                 NaN  2021-11-12 13:31:06
# 22                    NaN                 NaN  2021-11-12 13:20:31
# 26                    NaN                 NaN  2021-11-12 13:30:25
# 27                    NaN                 NaN  2020-12-04 10:40:37
# ...                   ...                 ...                  ...
# 42564                 NaN                 NaN  2021-11-12 13:20:31
# 42570                 NaN                 NaN  2021-11-12 13:33:19
# 42585                 NaN                 NaN  2022-05-06 11:30:06
# 42604                 NaN                 NaN  2021-11-12 13:25:14
# 42607                 NaN                 NaN  2021-11-12 13:23:03
#
#               date_updated  source  \
# 0      2021-11-19 17:44:45  baania
# 17     2021-03-18 16:04:05  baania
# 22     2020-10-14 00:55:39  baania
# 26     2021-02-18 10:34:04  baania
# 27     2020-10-14 01:04:23  baania
# ...                    ...     ...
# 42564  2020-10-14 00:55:39  baania
# 42570  2021-07-13 11:11:20  baania
# 42585  2022-05-06 11:17:03  baania
# 42604  2020-10-27 15:03:40  baania
# 42607  2020-10-14 20:30:43  baania
#
#                                             url_unittype       province
# 0      https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...  กรุงเทพมหานคร
# 17     https://baania.com/th/project/ศุภาลัย-ซิตี้-รี...  กรุงเทพมหานคร
# 22     https://baania.com/th/project/เดอะ-ทรีโอ-การ์เ...  กรุงเทพมหานคร
# 26     https://baania.com/th/project/ปาร์ค-พุทธบูชา-4...  กรุงเทพมหานคร
# 27     https://baania.com/th/project/เซอราโน่-คอนโดมิ...  กรุงเทพมหานคร
# ...                                                  ...            ...
# 42564  https://baania.com/th/project/เดอะ-ทรีโอ-การ์เ...  กรุงเทพมหานคร
# 42570  https://baania.com/th/project/เดอะ-คริส-เอ็กซ์...  กรุงเทพมหานคร
# 42585  https://baania.com/th/project/มาเอสโตร-14-สยาม...  กรุงเทพมหานคร
# 42604  https://baania.com/th/project/ศุภาลัย-ไลท์-รัช...  กรุงเทพมหานคร
# 42607  https://baania.com/th/project/เดอะ-ไลน์-สาทร-1...  กรุงเทพมหานคร
#
# [5425 rows x 28 columns]

# %%
unit_bkk_dth = bkk[(bkk['propertytype_name_en']=='Detached House')]
unit_bkk_dth
# Out:
#        row_number     unittype_id     project_id                   name_th  \
# 5           30766   unittype_8026   project_2694             Luciano Grand
# 11           2452   unittype_8521   project_2906        New Villa Valdivia
# 132          2448  unittype_16259   project_3141  บ้านเดี่ยวสองชั้น Type B
# 150           295   unittype_9071   project_3108                   Paradiz
# 167         26535  unittype_22997   project_8777           Grand Escalante
# ...           ...             ...            ...                       ...
# 42544       11175  unittype_29438  project_12199         บ้านเดี่ยวสองชั้น
# 42562       31445  unittype_20955   project_2681                 Chollatee
# 42572       27093  unittype_23444   project_9383  บ้านเดี่ยวสองชั้น Type C
# 42576       35213  unittype_22962   project_8609                 Manhattan
# 42623        9333  unittype_37375  project_16389       บ้านเดี่ยวชั้นเดียว
#
#        propertytype_id propertytype_name_en propertytype_name_th  \
# 5                    1       Detached House                 บ้าน
# 11                   1       Detached House                 บ้าน
# 132                  1       Detached House                 บ้าน
# 150                  1       Detached House                 บ้าน
# 167                  1       Detached House                 บ้าน
# ...                ...                  ...                  ...
# 42544                1       Detached House                 บ้าน
# 42562                1       Detached House                 บ้าน
# 42572                1       Detached House                 บ้าน
# 42576                1       Detached House                 บ้าน
# 42623                1       Detached House                 บ้าน
#
#        area_total_min_wa  area_usable_min   price_min  ...  \
# 5                   70.5            198.0  11700000.0  ...
# 11                   NaN            441.0  36900000.0  ...
# 132                  NaN            125.0   4000000.0  ...
# 150                 50.0            145.0   6790000.0  ...
# 167                  NaN            596.0  49800000.0  ...
# ...                  ...              ...         ...  ...
# 42544                NaN            200.0   6190000.0  ...
# 42562                NaN            412.0  28900000.0  ...
# 42572                NaN            180.0   3950000.0  ...
# 42576                NaN            465.0  28900000.0  ...
# 42623                NaN            180.0   3200000.0  ...
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 5                     NaN                NaN              NaN
# 11                    1.0                1.0              1.0
# 132                   1.0                NaN              NaN
# 150                   1.0                1.0              NaN
# 167                   1.0                NaN              2.0
# ...                   ...                ...              ...
# 42544                 NaN                NaN              NaN
# 42562                 NaN                NaN              NaN
# 42572                 1.0                NaN              NaN
# 42576                 2.0                2.0              1.0
# 42623                 1.0                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 5                     NaN                 NaN  2021-11-12 13:22:43
# 11                    NaN                 NaN  2021-11-12 13:22:43
# 132                   NaN                 NaN  2021-11-12 13:24:15
# 150                   NaN                 NaN  2021-11-12 13:31:25
# 167                   NaN                 NaN  2021-11-12 13:24:26
# ...                   ...                 ...                  ...
# 42544                 NaN                 NaN  2021-11-12 13:24:09
# 42562                 NaN                 NaN  2022-03-14 13:30:04
# 42572                 1.0                 NaN  2020-12-04 10:46:26
# 42576                 NaN                 NaN  2021-11-12 13:33:58
# 42623                 NaN                 NaN  2020-12-04 10:42:26
#
#               date_updated  source  \
# 5      2020-10-14 19:35:20  baania
# 11     2020-10-14 19:35:47  baania
# 132    2020-10-14 22:45:32  baania
# 150    2021-04-20 14:29:04  baania
# 167    2020-10-14 23:24:36  baania
# ...                    ...     ...
# 42544  2020-10-14 22:33:13  baania
# 42562  2022-03-14 13:18:45  baania
# 42572  2020-10-14 23:33:27  baania
# 42576  2021-10-03 15:21:58  baania
# 42623  2020-10-14 19:30:46  baania
#
#                                             url_unittype       province
# 5      https://baania.com/th/project/คาซ่า-แกรนด์-ตาก...  กรุงเทพมหานคร
# 11     https://baania.com/th/project/แกรนด์-บางกอก-บู...  กรุงเทพมหานคร
# 132    https://baania.com/th/project/ทาวน์พลัส-ประชาอ...  กรุงเทพมหานคร
# 150    https://baania.com/th/project/ภัสสร-เพรสทีจ-ลุ...  กรุงเทพมหานคร
# 167    https://baania.com/th/project/แกรนด์-บางกอก-บู...  กรุงเทพมหานคร
# ...                                                  ...            ...
# 42544  https://baania.com/th/project/เดอะโฮม-สวนผัก-6...  กรุงเทพมหานคร
# 42562  https://baania.com/th/project/ปริญญ์-สาทร-ราชพ...  กรุงเทพมหานคร
# 42572  https://baania.com/th/project/บ้านศิรินทรา-938...  กรุงเทพมหานคร
# 42576  https://baania.com/th/project/เดอะ-เจนทริ-สุขุ...  กรุงเทพมหานคร
# 42623  https://baania.com/th/project/ณรงค์กิจ-รามอินท...  กรุงเทพมหานคร
#
# [2610 rows x 28 columns]

# %% [markdown]
# ###ขอนแก่น

# %%
kk = unit[unit['province']=='ขอนแก่น']
kk
# Out:
#        row_number               unittype_id                project_id  \
# 8           41823  6215b4a7a441d30014e1f02f  6215b1cfc1620300140bc087
# 16          41850  621700a8a441d30014e1f0f3  6216fee6a441d30014e1f0f2
# 105          9355            unittype_37999              project_1865
# 116          5619             unittype_8484              project_2887
# 151         35385             unittype_6023              project_1905
# ...           ...                       ...                       ...
# 42441       35359             unittype_8257              project_1887
# 42518       19327  5ffd25870b458100134e46f8  5ffd2517a7d2770012bceb17
# 42547       13609            unittype_40203             project_17526
# 42559       41726  62064027591c4600138e62fb  600001780b458100134e49cb
# 42596       19373  5ffebd88a7d2770012bced13  5ffebcf0a7d2770012bced11
#
#                           name_th  propertytype_id propertytype_name_en  \
# 8      บ้านเดี่ยวชั้นเดียว Type C                1       Detached House
# 16            บ้านเดี่ยวชั้นเดียว                1       Detached House
# 105                        Type D                2                Condo
# 116      บ้านเดี่ยวสองชั้น Type B                1       Detached House
# 151                        Type S                2                Condo
# ...                           ...              ...                  ...
# 42441                 การะเกดพลัส                1       Detached House
# 42518           บ้านเดี่ยวสองชั้น                1       Detached House
# 42547             ทาวน์โฮมสองชั้น                3             Townhome
# 42559                Twin Stylist            20000           Twin house
# 42596         บ้านเดี่ยวชั้นเดียว                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 8                     บ้าน                NaN             80.0   990000.0
# 16                    บ้าน                NaN             83.0  2200000.0
# 105                  คอนโด                NaN             51.0  2240000.0
# 116                   บ้าน                NaN            260.0  4423000.0
# 151                  คอนโด                NaN             28.0  1450000.0
# ...                    ...                ...              ...        ...
# 42441                 บ้าน               60.0            141.0  2990000.0
# 42518                 บ้าน                NaN            116.0  2690000.0
# 42547             ทาวน์โฮม                NaN            101.0  1710000.0
# 42559              บ้านแฝด                NaN             95.0  1990000.0
# 42596                 บ้าน                NaN            142.0  2690000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 8      ...                 NaN                NaN              NaN
# 16     ...                 NaN                NaN              NaN
# 105    ...                 NaN                NaN              NaN
# 116    ...                 1.0                NaN              NaN
# 151    ...                 1.0                1.0              NaN
# ...    ...                 ...                ...              ...
# 42441  ...                 1.0                NaN              NaN
# 42518  ...                 1.0                NaN              NaN
# 42547  ...                 NaN                NaN              NaN
# 42559  ...                 NaN                NaN              NaN
# 42596  ...                 1.0                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 8                     NaN                 NaN  2022-02-23 12:00:12
# 16                    NaN                 NaN  2022-02-24 12:00:06
# 105                   NaN                 NaN  2022-02-23 12:00:12
# 116                   NaN                 NaN  2020-12-04 10:39:17
# 151                   NaN                 NaN  2022-02-24 12:00:07
# ...                   ...                 ...                  ...
# 42441                 1.0                 NaN  2022-02-23 14:30:06
# 42518                 NaN                 NaN  2022-02-11 11:00:07
# 42547                 NaN                 NaN  2022-02-23 10:30:03
# 42559                 NaN                 NaN  2022-02-11 18:30:06
# 42596                 NaN                 NaN  2022-02-14 09:30:04
#
#               date_updated  source  \
# 8      2022-02-23 11:14:31  baania
# 16     2022-02-24 11:38:52  baania
# 105    2022-02-23 11:33:01  baania
# 116    2020-10-14 00:54:48  baania
# 151    2022-02-24 11:48:50  baania
# ...                    ...     ...
# 42441  2022-02-23 14:27:15  baania
# 42518  2022-02-11 10:24:42  baania
# 42547  2022-02-23 10:02:59  baania
# 42559  2022-02-11 17:54:38  baania
# 42596  2022-02-11 19:32:16  baania
#
#                                             url_unittype  province
# 8      https://baania.com/th/project/เฌอลินน์ดา-ซำสูง...   ขอนแก่น
# 16     https://baania.com/th/project/อินทรวิลเลจ-6216...   ขอนแก่น
# 105    https://baania.com/th/project/ซิตี้-พาร์ค-คอนโ...   ขอนแก่น
# 116    https://baania.com/th/project/บ้านสุพัชรี-ริมบ...   ขอนแก่น
# 151    https://baania.com/th/project/เซเรนิตี้-คอนโดม...   ขอนแก่น
# ...                                                  ...       ...
# 42441  https://baania.com/th/project/กลันตา-เหล่านาดี...   ขอนแก่น
# 42518  https://baania.com/th/project/สุณภัทร-5ffd2517...   ขอนแก่น
# 42547  https://baania.com/th/project/ศุภาลัย-บลิซ-มะล...   ขอนแก่น
# 42559  https://baania.com/th/project/เดอะ-ริคโค่-ขอนแ...   ขอนแก่น
# 42596  https://baania.com/th/project/สไมล์โฮม-ขอนแก่น...   ขอนแก่น
#
# [760 rows x 28 columns]

# %%
unit_kk = kk[(kk['propertytype_name_en']=='Condo') | (kk['propertytype_name_en']=='Detached House')]
unit_kk.head()
# Out:
#      row_number               unittype_id                project_id  \
# 8         41823  6215b4a7a441d30014e1f02f  6215b1cfc1620300140bc087
# 16        41850  621700a8a441d30014e1f0f3  6216fee6a441d30014e1f0f2
# 105        9355            unittype_37999              project_1865
# 116        5619             unittype_8484              project_2887
# 151       35385             unittype_6023              project_1905
#
#                         name_th  propertytype_id propertytype_name_en  \
# 8    บ้านเดี่ยวชั้นเดียว Type C                1       Detached House
# 16          บ้านเดี่ยวชั้นเดียว                1       Detached House
# 105                      Type D                2                Condo
# 116    บ้านเดี่ยวสองชั้น Type B                1       Detached House
# 151                      Type S                2                Condo
#
#     propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 8                   บ้าน                NaN             80.0   990000.0  ...
# 16                  บ้าน                NaN             83.0  2200000.0  ...
# 105                คอนโด                NaN             51.0  2240000.0  ...
# 116                 บ้าน                NaN            260.0  4423000.0  ...
# 151                คอนโด                NaN             28.0  1450000.0  ...
#
#      count_room_kitchen  count_room_living  count_room_maid  \
# 8                   NaN                NaN              NaN
# 16                  NaN                NaN              NaN
# 105                 NaN                NaN              NaN
# 116                 1.0                NaN              NaN
# 151                 1.0                1.0              NaN
#
#      count_room_storage  count_room_utility         date_created  \
# 8                   NaN                 NaN  2022-02-23 12:00:12
# 16                  NaN                 NaN  2022-02-24 12:00:06
# 105                 NaN                 NaN  2022-02-23 12:00:12
# 116                 NaN                 NaN  2020-12-04 10:39:17
# 151                 NaN                 NaN  2022-02-24 12:00:07
#
#             date_updated  source  \
# 8    2022-02-23 11:14:31  baania
# 16   2022-02-24 11:38:52  baania
# 105  2022-02-23 11:33:01  baania
# 116  2020-10-14 00:54:48  baania
# 151  2022-02-24 11:48:50  baania
#
#                                           url_unittype  province
# 8    https://baania.com/th/project/เฌอลินน์ดา-ซำสูง...   ขอนแก่น
# 16   https://baania.com/th/project/อินทรวิลเลจ-6216...   ขอนแก่น
# 105  https://baania.com/th/project/ซิตี้-พาร์ค-คอนโ...   ขอนแก่น
# 116  https://baania.com/th/project/บ้านสุพัชรี-ริมบ...   ขอนแก่น
# 151  https://baania.com/th/project/เซเรนิตี้-คอนโดม...   ขอนแก่น
#
# [5 rows x 28 columns]

# %%
unit_kk_condo = kk[(kk['propertytype_name_en']=='Condo')]
unit_kk_condo
# Out:
#        row_number               unittype_id                project_id  \
# 105          9355            unittype_37999              project_1865
# 151         35385             unittype_6023              project_1905
# 535         35410             unittype_5814              project_1910
# 591         35489             unittype_8305              project_2811
# 1389        35408             unittype_5818              project_1909
# ...           ...                       ...                       ...
# 38252        5614             unittype_6830              project_2278
# 38823       15479  5ea27ebb78b3120012dd4c72  5ea27d8078b3120012dd4c70
# 40607       35450             unittype_5866              project_1926
# 41232       35416             unittype_5825              project_1911
# 42207       35312             unittype_5653              project_1870
#
#                      name_th  propertytype_id propertytype_name_en  \
# 105                   Type D                2                Condo
# 151                   Type S                2                Condo
# 535                   Type A                2                Condo
# 591                   Type A                2                Condo
# 1389      1 Bedroom En-Suite                2                Condo
# ...                      ...              ...                  ...
# 38252  เดอะโฟกัสคอนโดมิเนียม                2                Condo
# 38823              1 Bedroom                2                Condo
# 40607                 Type-A                2                Condo
# 41232                 Type L                2                Condo
# 42207                Type B4                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 105                  คอนโด                NaN             51.0  2240000.0
# 151                  คอนโด                NaN             28.0  1450000.0
# 535                  คอนโด                NaN             34.0  1890000.0
# 591                  คอนโด                NaN             34.0  1300000.0
# 1389                 คอนโด                NaN             41.0  2140000.0
# ...                    ...                ...              ...        ...
# 38252                คอนโด                NaN             23.0   590000.0
# 38823                คอนโด                NaN             29.0  1420000.0
# 40607                คอนโด                NaN             26.0  1390000.0
# 41232                คอนโด                NaN             47.0  2100000.0
# 42207                คอนโด                NaN             44.0  2650000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 105    ...                 NaN                NaN              NaN
# 151    ...                 1.0                1.0              NaN
# 535    ...                 1.0                NaN              NaN
# 591    ...                 1.0                NaN              NaN
# 1389   ...                 NaN                1.0              NaN
# ...    ...                 ...                ...              ...
# 38252  ...                 NaN                NaN              NaN
# 38823  ...                 NaN                NaN              NaN
# 40607  ...                 1.0                1.0              NaN
# 41232  ...                 NaN                NaN              NaN
# 42207  ...                 1.0                1.0              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 105                   NaN                 NaN  2022-02-23 12:00:12
# 151                   NaN                 NaN  2022-02-24 12:00:07
# 535                   NaN                 NaN  2022-02-24 16:30:06
# 591                   NaN                 NaN  2022-02-25 10:30:06
# 1389                  NaN                 NaN  2022-02-24 15:30:06
# ...                   ...                 ...                  ...
# 38252                 NaN                 NaN  2021-11-12 13:23:33
# 38823                 NaN                 NaN  2022-02-11 15:30:03
# 40607                 NaN                 NaN  2021-11-12 13:33:29
# 41232                 NaN                 NaN  2021-11-12 13:22:34
# 42207                 NaN                 NaN  2022-02-23 12:00:14
#
#               date_updated  source  \
# 105    2022-02-23 11:33:01  baania
# 151    2022-02-24 11:48:50  baania
# 535    2022-02-24 16:09:47  baania
# 591    2022-02-25 10:12:12  baania
# 1389   2022-02-24 15:22:55  baania
# ...                    ...     ...
# 38252  2020-10-14 20:56:42  baania
# 38823  2022-02-11 14:59:37  baania
# 40607  2021-07-15 15:06:32  baania
# 41232  2020-10-14 01:10:59  baania
# 42207  2022-02-23 11:47:46  baania
#
#                                             url_unittype  province
# 105    https://baania.com/th/project/ซิตี้-พาร์ค-คอนโ...   ขอนแก่น
# 151    https://baania.com/th/project/เซเรนิตี้-คอนโดม...   ขอนแก่น
# 535    https://baania.com/th/project/ชิค-คอนโด-1910/t...   ขอนแก่น
# 591    https://baania.com/th/project/เอ็กซ์เท็น-คอนโด...   ขอนแก่น
# 1389   https://baania.com/th/project/ไฮด์-คอนโด-1909/...   ขอนแก่น
# ...                                                  ...       ...
# 38252  https://baania.com/th/project/เดอะโฟกัสคอนโดมิ...   ขอนแก่น
# 38823  https://baania.com/th/project/ฉัตรเพชร-พาร์ค-ค...   ขอนแก่น
# 40607  https://baania.com/th/project/ฉัตรเพชร-ซีไนน์-...   ขอนแก่น
# 41232  https://baania.com/th/project/ดิคลาสเซ่-คอนโดม...   ขอนแก่น
# 42207  https://baania.com/th/project/ดิ-ไอซิส-คอนโด-1...   ขอนแก่น
#
# [111 rows x 28 columns]

# %%
plt.boxplot(unit_kk_condo['price_min']) ;

# %%
unit_kk_dth = kk[(kk['propertytype_name_en']=='Detached House')]
unit_kk_dth
# Out:
#        row_number               unittype_id                project_id  \
# 8           41823  6215b4a7a441d30014e1f02f  6215b1cfc1620300140bc087
# 16          41850  621700a8a441d30014e1f0f3  6216fee6a441d30014e1f0f2
# 116          5619             unittype_8484              project_2887
# 156         41794  621323afc1620300140bbfbb  62132270412ede001495e28d
# 284          8752            unittype_37166             project_16293
# ...           ...                       ...                       ...
# 42267       13482            unittype_39949             project_17419
# 42380       23816             unittype_5729              project_1897
# 42441       35359             unittype_8257              project_1887
# 42518       19327  5ffd25870b458100134e46f8  5ffd2517a7d2770012bceb17
# 42596       19373  5ffebd88a7d2770012bced13  5ffebcf0a7d2770012bced11
#
#                           name_th  propertytype_id propertytype_name_en  \
# 8      บ้านเดี่ยวชั้นเดียว Type C                1       Detached House
# 16            บ้านเดี่ยวชั้นเดียว                1       Detached House
# 116      บ้านเดี่ยวสองชั้น Type B                1       Detached House
# 156           บ้านเดี่ยวชั้นเดียว                1       Detached House
# 284                        Luxury                1       Detached House
# ...                           ...              ...                  ...
# 42267                       Aster                1       Detached House
# 42380              ศุภดรัล (ใหม่)                1       Detached House
# 42441                 การะเกดพลัส                1       Detached House
# 42518           บ้านเดี่ยวสองชั้น                1       Detached House
# 42596         บ้านเดี่ยวชั้นเดียว                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 8                     บ้าน                NaN             80.0   990000.0
# 16                    บ้าน                NaN             83.0  2200000.0
# 116                   บ้าน                NaN            260.0  4423000.0
# 156                   บ้าน                NaN            130.0  2250000.0
# 284                   บ้าน               70.0            200.0  4890000.0
# ...                    ...                ...              ...        ...
# 42267                 บ้าน                NaN             90.0  2100000.0
# 42380                 บ้าน               77.0            171.0  3070000.0
# 42441                 บ้าน               60.0            141.0  2990000.0
# 42518                 บ้าน                NaN            116.0  2690000.0
# 42596                 บ้าน                NaN            142.0  2690000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 8      ...                 NaN                NaN              NaN
# 16     ...                 NaN                NaN              NaN
# 116    ...                 1.0                NaN              NaN
# 156    ...                 NaN                NaN              NaN
# 284    ...                 NaN                NaN              NaN
# ...    ...                 ...                ...              ...
# 42267  ...                 1.0                NaN              NaN
# 42380  ...                 1.0                NaN              NaN
# 42441  ...                 1.0                NaN              NaN
# 42518  ...                 1.0                NaN              NaN
# 42596  ...                 1.0                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 8                     NaN                 NaN  2022-02-23 12:00:12
# 16                    NaN                 NaN  2022-02-24 12:00:06
# 116                   NaN                 NaN  2020-12-04 10:39:17
# 156                   NaN                 NaN  2022-02-21 14:00:11
# 284                   NaN                 NaN  2022-02-16 16:00:10
# ...                   ...                 ...                  ...
# 42267                 NaN                 NaN  2022-02-22 17:00:11
# 42380                 1.0                 NaN  2021-11-12 13:17:12
# 42441                 1.0                 NaN  2022-02-23 14:30:06
# 42518                 NaN                 NaN  2022-02-11 11:00:07
# 42596                 NaN                 NaN  2022-02-14 09:30:04
#
#               date_updated  source  \
# 8      2022-02-23 11:14:31  baania
# 16     2022-02-24 11:38:52  baania
# 116    2020-10-14 00:54:48  baania
# 156    2022-02-21 12:31:27  baania
# 284    2022-02-16 15:33:48  baania
# ...                    ...     ...
# 42267  2022-02-22 16:33:28  baania
# 42380  2017-05-29 12:33:38  baania
# 42441  2022-02-23 14:27:15  baania
# 42518  2022-02-11 10:24:42  baania
# 42596  2022-02-11 19:32:16  baania
#
#                                             url_unittype  province
# 8      https://baania.com/th/project/เฌอลินน์ดา-ซำสูง...   ขอนแก่น
# 16     https://baania.com/th/project/อินทรวิลเลจ-6216...   ขอนแก่น
# 116    https://baania.com/th/project/บ้านสุพัชรี-ริมบ...   ขอนแก่น
# 156    https://baania.com/th/project/ดิเอมวิลล์-62132...   ขอนแก่น
# 284    https://baania.com/th/project/ชลพฤกษ์-พาร์ควิล...   ขอนแก่น
# ...                                                  ...       ...
# 42267  https://baania.com/th/project/เดอะทาวน์-ขอนแก่...   ขอนแก่น
# 42380  https://baania.com/th/project/ศุภาลัย-รอยัลริเ...   ขอนแก่น
# 42441  https://baania.com/th/project/กลันตา-เหล่านาดี...   ขอนแก่น
# 42518  https://baania.com/th/project/สุณภัทร-5ffd2517...   ขอนแก่น
# 42596  https://baania.com/th/project/สไมล์โฮม-ขอนแก่น...   ขอนแก่น
#
# [516 rows x 28 columns]

# %%
plt.boxplot(unit_kk_dth['price_min']) ;

# %% [markdown]
# ### รวม

# %%
plt.subplot(2,3,1)
plt.boxplot(unit_kk_dth['price_min'])
plt.title('Home_kk')

plt.subplot(2,3,2)
plt.boxplot(unit_bkk_dth['price_min'])
plt.title('Home_bkk')

plt.subplot(2,3,3)
plt.boxplot(unit_cm_dth['price_min'])
plt.title('Home_cm')

plt.subplot(2,3,4)
plt.boxplot(unit_kk_condo['price_min'])
plt.title('Condo_kk')

plt.subplot(2,3,5)
plt.boxplot(unit_bkk_condo['price_min'])
plt.title('Condo_bkk')

plt.subplot(2,3,6)
plt.boxplot(unit_cm_condo['price_min'])  ;
plt.title('Condo_cm')
# Out:
# Text(0.5, 1.0, 'Condo_cm')
